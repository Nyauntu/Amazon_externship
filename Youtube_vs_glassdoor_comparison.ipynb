# %% [markdown]
# <a href="https://colab.research.google.com/github/Nyauntu/Amazon_externship/blob/main/Youtube_vs_glassdoor_comparison.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

glassdoor_df = pd.read_csv('/content/glassdoor_sentiment.csv')
youtube_df = pd.read_csv('/content/youtube_sentiment.csv')

# %%
glassdoor_counts = glassdoor_df['sentiment_label'].value_counts(normalize=True)
youtube_counts = youtube_df['sentiment_label'].value_counts(normalize=True)

print("Glassdoor Sentiment Breakdown:\n", glassdoor_counts)
print("\nYouTube Sentiment Breakdown:\n", youtube_counts)
# Out:
# Glassdoor Sentiment Breakdown:
#  sentiment_label
# positive    0.441176
# neutral     0.411765
# negative    0.147059
# Name: proportion, dtype: float64
#
# YouTube Sentiment Breakdown:
#  sentiment_label
# neutral     0.8
# positive    0.2
# Name: proportion, dtype: float64

# %%
import matplotlib.pyplot as plt

comparison_df = pd.DataFrame({
    'Glassdoor': glassdoor_counts,
    'YouTube': youtube_counts
})

comparison_df.plot(kind='bar')
plt.title("Sentiment Comparison: Glassdoor vs. YouTube")
plt.xlabel("Sentiment")
plt.ylabel("Proportion of Reviews")
plt.xticks(rotation=0)
plt.legend(loc='upper right')
plt.tight_layout()
plt.show()
